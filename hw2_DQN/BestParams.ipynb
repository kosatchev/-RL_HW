# %%
# !pip install gym tensorboard
# !pip install gym[other]
# !pip install gym[atari,accept-rom-license]

# %% [markdown]
# # Запуск обучения с лучшими параметрами

# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
from torch.utils.tensorboard import SummaryWriter
import os
from matplotlib import pyplot as plt
from gym.wrappers import RecordVideo
from IPython.display import HTML
import base64
import glob
# %matplotlib inline

# Гиперпараметры
BATCH_SIZE = 32
MEMORY_SIZE = 100_000
LEARNING_STARTS = 10_000
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.05
EXPLORATION_FRACTION = 0.3
EPS_DECAY = int(EXPLORATION_FRACTION * MEMORY_SIZE)
TARGET_UPDATE = 1000
LEARNING_RATE = 1e-4
FRAME_STACK = 4
NUM_EPISODES = 2000
TRAIN_FREQ = 4
MAX_GRAD_NORM = 10
TENSORBOARD_LOGDIR = "./dqn_pong_improved_tensorboard/"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Настройка TensorBoard
os.makedirs(TENSORBOARD_LOGDIR, exist_ok=True)
writer = SummaryWriter(log_dir=TENSORBOARD_LOGDIR)

# Инициализация среды для Pong
env = gym.make('ALE/Pong-v5',
               obs_type='rgb',
               frameskip=4,
               repeat_action_probability=0.25,
               render_mode='rgb_array')
env = gym.wrappers.ResizeObservation(env, (84, 84))
env = gym.wrappers.GrayScaleObservation(env)
env = gym.wrappers.FrameStack(env, FRAME_STACK)

# DQN модель
class DQN(nn.Module):
    def __init__(self, n_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(FRAME_STACK, 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)
        self.fc1 = nn.Linear(3136, 512)
        self.out = nn.Linear(512, n_actions)

    def forward(self, x):
        x = x.float() / 255.0
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.out(x)

# Буфер повторов
class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, size):
        return random.sample(self.buffer, size)

    def __len__(self):
        return len(self.buffer)

n_actions = env.action_space.n
policy_net = DQN(n_actions).to(device)
target_net = DQN(n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)
memory = ReplayMemory(MEMORY_SIZE)
steps_done = 0

# Дополнительные массивы для логирования
eps_history = []
q_value_history = []

def process_frame(frame):
    frame = np.array(frame)
    return torch.from_numpy(frame).unsqueeze(0).to(device)

def select_action(state):
    global steps_done
    eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-steps_done / EPS_DECAY)
    steps_done += 1
    if random.random() > eps_threshold:
        with torch.no_grad():
            return policy_net(state).argmax(dim=1, keepdim=True)
    else:
        return torch.tensor([[env.action_space.sample()]], dtype=torch.long, device=device)

def optimize():
    if len(memory) < BATCH_SIZE or steps_done < LEARNING_STARTS:
        return 0.0

    transitions = memory.sample(BATCH_SIZE)
    batch = list(zip(*transitions))

    states = torch.cat(batch[0])
    actions = torch.cat(batch[1])
    rewards = torch.cat(batch[2])
    dones = torch.cat(batch[4])

    non_final_mask = torch.tensor([s is not None for s in batch[3]], device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch[3] if s is not None]) if any(non_final_mask) else None

    current_q = policy_net(states).gather(1, actions)

    next_q = torch.zeros(BATCH_SIZE, device=device)
    if non_final_next_states is not None:
        next_q[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()

    target_q = rewards + (1.0 - dones) * GAMMA * next_q
    loss = F.mse_loss(current_q.squeeze(), target_q)

    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(policy_net.parameters(), MAX_GRAD_NORM)
    optimizer.step()

    return loss.item()

# Основной цикл обучения
episode_rewards = []
loss_history = []

for episode in range(NUM_EPISODES):
    obs, _ = env.reset()
    state = process_frame(obs)
    total_reward = 0
    done = False

    while not done:
        action = select_action(state)
        next_obs, reward, terminated, truncated, _ = env.step(action.item())
        done = terminated or truncated
        total_reward += reward

        next_state = process_frame(next_obs) if not done else None

        memory.push(state,
                    action,
                    torch.tensor([reward], dtype=torch.float32, device=device),
                    next_state,
                    torch.tensor([done], dtype=torch.float32, device=device))

        state = next_state if next_state is not None else state

        if steps_done % TRAIN_FREQ == 0:
            loss = optimize()
            loss_history.append(loss)
            writer.add_scalar("Loss", loss, steps_done)

            eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-steps_done / EPS_DECAY)
            writer.add_scalar("Epsilon", eps_threshold, steps_done)
            eps_history.append(eps_threshold)

            if len(memory) >= BATCH_SIZE:
                sample_transitions = memory.sample(BATCH_SIZE)
                sample_states = torch.cat([s for (s, _, _, _, _) in sample_transitions])
                with torch.no_grad():
                    q_values = policy_net(sample_states)
                avg_q = q_values.max(1)[0].mean().item()
                writer.add_scalar("Avg_Q", avg_q, steps_done)
                q_value_history.append(avg_q)

        if steps_done % TARGET_UPDATE == 0:
            target_net.load_state_dict(policy_net.state_dict())

    episode_rewards.append(total_reward)
    writer.add_scalar("Reward", total_reward, episode)

    if episode % 10 == 0:
        avg_reward = np.mean(episode_rewards[-10:])
        avg_loss = np.mean(loss_history[-100:]) if loss_history else 0
        print(f"Episode {episode:4d} | Avg Reward: {avg_reward:6.2f} | Loss: {avg_loss:6.4f}")

# Сохранение модели
torch.save(policy_net.state_dict(), "dqn_pong_improved.pth")


# Построение графиков
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs[0, 0].set_title("Episode Rewards")
axs[0, 0].plot(episode_rewards)
axs[0, 0].set_xlabel("Episode")
axs[0, 0].set_ylabel("Reward")

axs[0, 1].set_title("Training Loss")
axs[0, 1].plot(loss_history)
axs[0, 1].set_xlabel("Training Steps")
axs[0, 1].set_ylabel("Loss")

axs[1, 0].set_title("Epsilon Decay")
axs[1, 0].plot(eps_history)
axs[1, 0].set_xlabel("Training Steps")
axs[1, 0].set_ylabel("Epsilon")

axs[1, 1].set_title("Average Q-Value")
axs[1, 1].plot(q_value_history)
axs[1, 1].set_xlabel("Training Steps")
axs[1, 1].set_ylabel("Avg Q")

plt.tight_layout()
plt.show()

env.close()
writer.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode    0 | Avg Reward: -21.00 | Loss: 0.0000
# Episode   10 | Avg Reward: -20.70 | Loss: 0.0000
# Episode   20 | Avg Reward: -20.50 | Loss: 0.0185
# Episode   30 | Avg Reward: -20.70 | Loss: 0.0143
# Episode   40 | Avg Reward: -20.80 | Loss: 0.0155
# Episode   50 | Avg Reward: -20.50 | Loss: 0.0117
# Episode   60 | Avg Reward: -20.40 | Loss: 0.0101
# Episode   70 | Avg Reward: -20.70 | Loss: 0.0067
# Episode   80 | Avg Reward: -20.90 | Loss: 0.0082
# Episode   90 | Avg Reward: -20.70 | Loss: 0.0060
# Episode  100 | Avg Reward: -20.80 | Loss: 0.0067
# Episode  110 | Avg Reward: -20.50 | Loss: 0.0078
# Episode  120 | Avg Reward: -21.00 | Loss: 0.0064
# Episode  130 | Avg Reward: -20.90 | Loss: 0.0064
# Episode  140 | Avg Reward: -20.90 | Loss: 0.0062
# Episode  150 | Avg Reward: -20.80 | Loss: 0.0058
# Episode  160 | Avg Reward: -20.90 | Loss: 0.0072
# Episode  170 | Avg Reward: -20.70 | Loss: 0.0051
# Episode  180 | Avg Reward: -20.80 | Loss: 0.0060
# Episode  190 | Avg Reward: -20.70 | Loss: 0.0063
# Episode  200 | Avg Reward: -20.70 | Loss: 0.0060
# Episode  210 | Avg Reward: -20.90 | Loss: 0.0062
# Episode  220 | Avg Reward: -20.50 | Loss: 0.0069
# Episode  230 | Avg Reward: -20.30 | Loss: 0.0080
# Episode  240 | Avg Reward: -19.90 | Loss: 0.0069
# Episode  250 | Avg Reward: -18.50 | Loss: 0.0091
# Episode  260 | Avg Reward: -18.50 | Loss: 0.0080
# Episode  270 | Avg Reward: -17.90 | Loss: 0.0078
# Episode  280 | Avg Reward: -17.30 | Loss: 0.0084
# Episode  290 | Avg Reward: -16.10 | Loss: 0.0071
# Episode  300 | Avg Reward: -16.00 | Loss: 0.0078
# Episode  310 | Avg Reward: -17.50 | Loss: 0.0068
# Episode  320 | Avg Reward: -16.60 | Loss: 0.0086
# Episode  330 | Avg Reward: -14.50 | Loss: 0.0075
# Episode  340 | Avg Reward: -12.60 | Loss: 0.0074
# Episode  350 | Avg Reward: -11.40 | Loss: 0.0076
# Episode  360 | Avg Reward: -14.70 | Loss: 0.0082
# Episode  370 | Avg Reward: -15.30 | Loss: 0.0078
# Episode  380 | Avg Reward: -13.50 | Loss: 0.0071
# Episode  390 | Avg Reward: -14.30 | Loss: 0.0068
# Episode  400 | Avg Reward: -12.80 | Loss: 0.0070
# Episode  410 | Avg Reward: -14.30 | Loss: 0.0072
# Episode  420 | Avg Reward: -12.90 | Loss: 0.0070
# Episode  430 | Avg Reward: -13.90 | Loss: 0.0060
# Episode  440 | Avg Reward: -14.00 | Loss: 0.0057
# Episode  450 | Avg Reward: -10.30 | Loss: 0.0055
# Episode  460 | Avg Reward:  -9.60 | Loss: 0.0056
# Episode  470 | Avg Reward:  -8.90 | Loss: 0.0079
# Episode  480 | Avg Reward:  -6.70 | Loss: 0.0070
# Episode  490 | Avg Reward:  -7.80 | Loss: 0.0089
# Episode  500 | Avg Reward:  -5.30 | Loss: 0.0057
# Episode  510 | Avg Reward:  -6.10 | Loss: 0.0059
# Episode  520 | Avg Reward:  -3.80 | Loss: 0.0073
# Episode  530 | Avg Reward:  -3.70 | Loss: 0.0065
# Episode  540 | Avg Reward:  -4.30 | Loss: 0.0062
# Episode  550 | Avg Reward:   2.20 | Loss: 0.0063
# Episode  560 | Avg Reward:  -2.40 | Loss: 0.0064
# Episode  570 | Avg Reward:   4.80 | Loss: 0.0062
# Episode  580 | Avg Reward:   2.60 | Loss: 0.0064
# Episode  590 | Avg Reward:   7.60 | Loss: 0.0045
# Episode  600 | Avg Reward:   5.00 | Loss: 0.0051
# Episode  610 | Avg Reward:   2.80 | Loss: 0.0060
# Episode  620 | Avg Reward:   3.40 | Loss: 0.0051
# Episode  630 | Avg Reward:   3.10 | Loss: 0.0050
# Episode  640 | Avg Reward:   7.20 | Loss: 0.0051
# Episode  650 | Avg Reward:   2.80 | Loss: 0.0057
# Episode  660 | Avg Reward:   5.50 | Loss: 0.0058
# Episode  670 | Avg Reward:   6.20 | Loss: 0.0051
# Episode  680 | Avg Reward:   8.60 | Loss: 0.0058
# Episode  690 | Avg Reward:   9.70 | Loss: 0.0042
# Episode  700 | Avg Reward:   8.80 | Loss: 0.0049
# Episode  710 | Avg Reward:  11.90 | Loss: 0.0040
# Episode  720 | Avg Reward:   9.10 | Loss: 0.0043
# Episode  730 | Avg Reward:   6.10 | Loss: 0.0056
# Episode  740 | Avg Reward:  10.60 | Loss: 0.0052
# Episode  750 | Avg Reward:   6.20 | Loss: 0.0046
# Episode  760 | Avg Reward:   6.30 | Loss: 0.0048
# Episode  770 | Avg Reward:   9.80 | Loss: 0.0057
# Episode  780 | Avg Reward:   5.60 | Loss: 0.0053
# Episode  790 | Avg Reward:  10.00 | Loss: 0.0044
# Episode  800 | Avg Reward:  10.10 | Loss: 0.0044
# Episode  810 | Avg Reward:   8.80 | Loss: 0.0056
# Episode  820 | Avg Reward:   9.60 | Loss: 0.0049
# Episode  830 | Avg Reward:   9.70 | Loss: 0.0048
# Episode  840 | Avg Reward:  10.00 | Loss: 0.0054
# Episode  850 | Avg Reward:   9.80 | Loss: 0.0047
# Episode  860 | Avg Reward:  12.70 | Loss: 0.0043
# Episode  870 | Avg Reward:   5.70 | Loss: 0.0049
# Episode  880 | Avg Reward:  10.40 | Loss: 0.0052
# Episode  890 | Avg Reward:   8.00 | Loss: 0.0066
# Episode  900 | Avg Reward:  10.20 | Loss: 0.0051
# Episode  910 | Avg Reward:  12.00 | Loss: 0.0049
# Episode  920 | Avg Reward:  11.10 | Loss: 0.0047
# Episode  930 | Avg Reward:  10.70 | Loss: 0.0051
# Episode  940 | Avg Reward:  10.10 | Loss: 0.0049
# Episode  950 | Avg Reward:  10.00 | Loss: 0.0049
# Episode  960 | Avg Reward:  12.50 | Loss: 0.0048
# Episode  970 | Avg Reward:   9.60 | Loss: 0.0044
# Episode  980 | Avg Reward:   9.70 | Loss: 0.0054
# Episode  990 | Avg Reward:  10.40 | Loss: 0.0051
# Episode 1000 | Avg Reward:  14.80 | Loss: 0.0050
# Episode 1010 | Avg Reward:  12.30 | Loss: 0.0052
# Episode 1020 | Avg Reward:  10.80 | Loss: 0.0045
# Episode 1030 | Avg Reward:  11.00 | Loss: 0.0049
# Episode 1040 | Avg Reward:  10.10 | Loss: 0.0063
# Episode 1050 | Avg Reward:  11.90 | Loss: 0.0048
# Episode 1060 | Avg Reward:  11.00 | Loss: 0.0047
# Episode 1070 | Avg Reward:  12.10 | Loss: 0.0050
# Episode 1080 | Avg Reward:  10.60 | Loss: 0.0048
# Episode 1090 | Avg Reward:  15.30 | Loss: 0.0050
# Episode 1100 | Avg Reward:  12.00 | Loss: 0.0057
# Episode 1110 | Avg Reward:  13.90 | Loss: 0.0053
# Episode 1120 | Avg Reward:  14.20 | Loss: 0.0047
# Episode 1130 | Avg Reward:  11.30 | Loss: 0.0049
# Episode 1140 | Avg Reward:  14.20 | Loss: 0.0042
# Episode 1150 | Avg Reward:  14.90 | Loss: 0.0061
# Episode 1160 | Avg Reward:  13.30 | Loss: 0.0039
# Episode 1170 | Avg Reward:  15.00 | Loss: 0.0050
# Episode 1180 | Avg Reward:  15.00 | Loss: 0.0037
# Episode 1190 | Avg Reward:  14.20 | Loss: 0.0049
# Episode 1200 | Avg Reward:  13.70 | Loss: 0.0041
# Episode 1210 | Avg Reward:  13.40 | Loss: 0.0036
# Episode 1220 | Avg Reward:  13.30 | Loss: 0.0051
# Episode 1230 | Avg Reward:  12.90 | Loss: 0.0057
# Episode 1240 | Avg Reward:  10.90 | Loss: 0.0061
# Episode 1250 | Avg Reward:  12.80 | Loss: 0.0048
# Episode 1260 | Avg Reward:  11.70 | Loss: 0.0050
# Episode 1270 | Avg Reward:  13.40 | Loss: 0.0058
# Episode 1280 | Avg Reward:  13.60 | Loss: 0.0052
# Episode 1290 | Avg Reward:  14.20 | Loss: 0.0059
# Episode 1300 | Avg Reward:  11.90 | Loss: 0.0055
# Episode 1310 | Avg Reward:  12.30 | Loss: 0.0053
# Episode 1320 | Avg Reward:  12.90 | Loss: 0.0055
# Episode 1330 | Avg Reward:  12.70 | Loss: 0.0067
# Episode 1340 | Avg Reward:  13.20 | Loss: 0.0063
# Episode 1350 | Avg Reward:  11.40 | Loss: 0.0046
# Episode 1360 | Avg Reward:  12.40 | Loss: 0.0058
# Episode 1370 | Avg Reward:  13.90 | Loss: 0.0053
# Episode 1380 | Avg Reward:  14.00 | Loss: 0.0044
# Episode 1390 | Avg Reward:  12.90 | Loss: 0.0055
# Episode 1400 | Avg Reward:  14.90 | Loss: 0.0061
# Episode 1410 | Avg Reward:  13.00 | Loss: 0.0056
# Episode 1420 | Avg Reward:  13.40 | Loss: 0.0042
# Episode 1430 | Avg Reward:  14.00 | Loss: 0.0040
# Episode 1440 | Avg Reward:  15.30 | Loss: 0.0041
# Episode 1450 | Avg Reward:  13.50 | Loss: 0.0051
# Episode 1460 | Avg Reward:  11.20 | Loss: 0.0059
# Episode 1470 | Avg Reward:  13.60 | Loss: 0.0046
# Episode 1480 | Avg Reward:  14.00 | Loss: 0.0039
# Episode 1490 | Avg Reward:  13.30 | Loss: 0.0049
# Episode 1500 | Avg Reward:  15.50 | Loss: 0.0068
# Episode 1510 | Avg Reward:  14.40 | Loss: 0.0044
# Episode 1520 | Avg Reward:  13.90 | Loss: 0.0051
# Episode 1530 | Avg Reward:  14.40 | Loss: 0.0044
# Episode 1540 | Avg Reward:  14.50 | Loss: 0.0045
# Episode 1550 | Avg Reward:  12.70 | Loss: 0.0051
# Episode 1560 | Avg Reward:  14.80 | Loss: 0.0037
# Episode 1570 | Avg Reward:  13.00 | Loss: 0.0048
# Episode 1580 | Avg Reward:  13.50 | Loss: 0.0048
# Episode 1590 | Avg Reward:  14.90 | Loss: 0.0044
# Episode 1600 | Avg Reward:  14.70 | Loss: 0.0046
# Episode 1610 | Avg Reward:  14.00 | Loss: 0.0047
# Episode 1620 | Avg Reward:  13.60 | Loss: 0.0048
# Episode 1630 | Avg Reward:  15.70 | Loss: 0.0048
# Episode 1640 | Avg Reward:  11.90 | Loss: 0.0056
# Episode 1650 | Avg Reward:  13.90 | Loss: 0.0042
# Episode 1660 | Avg Reward:  15.10 | Loss: 0.0044
# Episode 1670 | Avg Reward:  15.50 | Loss: 0.0044
# Episode 1680 | Avg Reward:  13.80 | Loss: 0.0042
# Episode 1690 | Avg Reward:  15.60 | Loss: 0.0046
# Episode 1700 | Avg Reward:  12.70 | Loss: 0.0047
# Episode 1710 | Avg Reward:  14.30 | Loss: 0.0045
# Episode 1720 | Avg Reward:  14.50 | Loss: 0.0047
# Episode 1730 | Avg Reward:  14.40 | Loss: 0.0039
# Episode 1740 | Avg Reward:  15.00 | Loss: 0.0043
# Episode 1750 | Avg Reward:  15.20 | Loss: 0.0045
# Episode 1760 | Avg Reward:  12.80 | Loss: 0.0040
# Episode 1770 | Avg Reward:  14.70 | Loss: 0.0037
# Episode 1780 | Avg Reward:  15.40 | Loss: 0.0035
# Episode 1790 | Avg Reward:  15.10 | Loss: 0.0048
# Episode 1800 | Avg Reward:  13.50 | Loss: 0.0037
# Episode 1810 | Avg Reward:  16.40 | Loss: 0.0040
# Episode 1820 | Avg Reward:  13.90 | Loss: 0.0046
# Episode 1830 | Avg Reward:  14.40 | Loss: 0.0031
# Episode 1840 | Avg Reward:  15.00 | Loss: 0.0037
# Episode 1850 | Avg Reward:  15.90 | Loss: 0.0034
# Episode 1860 | Avg Reward:  15.50 | Loss: 0.0050
# Episode 1870 | Avg Reward:  13.10 | Loss: 0.0038
# Episode 1880 | Avg Reward:  14.40 | Loss: 0.0049
# Episode 1890 | Avg Reward:  14.30 | Loss: 0.0052
# Episode 1900 | Avg Reward:  13.90 | Loss: 0.0052
# Episode 1910 | Avg Reward:  14.00 | Loss: 0.0044
# Episode 1920 | Avg Reward:  13.00 | Loss: 0.0058
# Episode 1930 | Avg Reward:  16.00 | Loss: 0.0035
# Episode 1940 | Avg Reward:  13.30 | Loss: 0.0036
# Episode 1950 | Avg Reward:  14.00 | Loss: 0.0051
# Episode 1960 | Avg Reward:  14.80 | Loss: 0.0055
# Episode 1970 | Avg Reward:  13.80 | Loss: 0.0042
# Episode 1980 | Avg Reward:  16.30 | Loss: 0.0038
# Episode 1990 | Avg Reward:  14.80 | Loss: 0.0037

# %%
# -------------------------
# Демонстрация видео
# Создаём новую среду с записью видео
video_folder = "./video_pong"
os.makedirs(video_folder, exist_ok=True)
demo_env = gym.make('ALE/Pong-v5',
                    obs_type='rgb',
                    frameskip=4,
                    repeat_action_probability=0.25,
                    render_mode='rgb_array')
demo_env = gym.wrappers.ResizeObservation(demo_env, (84, 84))
demo_env = gym.wrappers.GrayScaleObservation(demo_env)
demo_env = gym.wrappers.FrameStack(demo_env, FRAME_STACK)
demo_env = RecordVideo(demo_env, video_folder=video_folder, episode_trigger=lambda ep: True)

obs, _ = demo_env.reset()
done = False
while not done:
    state = process_frame(obs)
    with torch.no_grad():
        action = policy_net(state).argmax(dim=1, keepdim=True)
    obs, reward, terminated, truncated, _ = demo_env.step(action.item())
    done = terminated or truncated
demo_env.close()

# Функция для отображения видео в Jupyter Notebook
def show_video(video_folder):
    mp4_files = glob.glob(os.path.join(video_folder, "*.mp4"))
    if len(mp4_files) > 0:
        video_path = mp4_files[0]
        video = open(video_path, "rb").read()
        video_encoded = base64.b64encode(video).decode("ascii")
        return HTML(f'<video width="640" height="480" controls><source src="data:video/mp4;base64,{video_encoded}" type="video/mp4"></video>')
    else:
        return "Видео не найдено"

# Отобразим видео
show_video(video_folder)
# Out:
# /opt/conda/lib/python3.11/site-packages/gym/wrappers/record_video.py:75: UserWarning: WARN: Overwriting existing videos at /home/jovyan/work/video_pong folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# MoviePy - Building video /home/jovyan/work/video_pong/rl-video-episode-0.mp4.
# MoviePy - Writing video /home/jovyan/work/video_pong/rl-video-episode-0.mp4
# MoviePy - Done !
# MoviePy - video ready /home/jovyan/work/video_pong/rl-video-episode-0.mp4
# <video width="640" height="480" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
import random
from torch.utils.tensorboard import SummaryWriter
import os
from matplotlib import pyplot as plt
from gym.wrappers import RecordVideo
from IPython.display import HTML
import base64
import glob
# %matplotlib inline

# Гиперпараметры
BATCH_SIZE = 32
MEMORY_SIZE = 200_000
LEARNING_STARTS = 10_000
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.05
EXPLORATION_FRACTION = 0.3
EPS_DECAY = int(EXPLORATION_FRACTION * MEMORY_SIZE)
TARGET_UPDATE = 1000
LEARNING_RATE = 2.5e-4
FRAME_STACK = 4
NUM_EPISODES = 2000
TRAIN_FREQ = 4
MAX_GRAD_NORM = 10
TENSORBOARD_LOGDIR = "./dqn_breakout_improved_tensorboard/"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Настройка TensorBoard
os.makedirs(TENSORBOARD_LOGDIR, exist_ok=True)
writer = SummaryWriter(log_dir=TENSORBOARD_LOGDIR)

# Инициализация среды для Breakout
env = gym.make('ALE/Breakout-v5',
               obs_type='rgb',
               frameskip=4,
               repeat_action_probability=0.25,
               render_mode='rgb_array')
env = gym.wrappers.ResizeObservation(env, (84, 84))
env = gym.wrappers.GrayScaleObservation(env)
env = gym.wrappers.FrameStack(env, FRAME_STACK)

# DQN модель
class DQN(nn.Module):
    def __init__(self, n_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(FRAME_STACK, 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)
        self.fc1 = nn.Linear(3136, 512)
        self.out = nn.Linear(512, n_actions)

    def forward(self, x):
        x = x.float() / 255.0
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.out(x)

# Буфер повторов
class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, size):
        return random.sample(self.buffer, size)

    def __len__(self):
        return len(self.buffer)

n_actions = env.action_space.n
policy_net = DQN(n_actions).to(device)
target_net = DQN(n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)
memory = ReplayMemory(MEMORY_SIZE)
steps_done = 0

# Дополнительные массивы для логирования
eps_history = []
q_value_history = []

def process_frame(frame):
    frame = np.array(frame)
    return torch.from_numpy(frame).unsqueeze(0).to(device)

def select_action(state):
    global steps_done
    eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-steps_done / EPS_DECAY)
    steps_done += 1
    if random.random() > eps_threshold:
        with torch.no_grad():
            return policy_net(state).argmax(dim=1, keepdim=True)
    else:
        return torch.tensor([[env.action_space.sample()]], dtype=torch.long, device=device)

def optimize():
    if len(memory) < BATCH_SIZE or steps_done < LEARNING_STARTS:
        return 0.0

    transitions = memory.sample(BATCH_SIZE)
    batch = list(zip(*transitions))

    states = torch.cat(batch[0])
    actions = torch.cat(batch[1])
    rewards = torch.cat(batch[2])
    dones = torch.cat(batch[4])

    non_final_mask = torch.tensor([s is not None for s in batch[3]], device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch[3] if s is not None]) if any(non_final_mask) else None

    current_q = policy_net(states).gather(1, actions)

    next_q = torch.zeros(BATCH_SIZE, device=device)
    if non_final_next_states is not None:
        next_q[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()

    target_q = rewards + (1.0 - dones) * GAMMA * next_q
    loss = F.mse_loss(current_q.squeeze(), target_q)

    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(policy_net.parameters(), MAX_GRAD_NORM)
    optimizer.step()

    return loss.item()

# Основной цикл обучения
episode_rewards = []
loss_history = []

for episode in range(NUM_EPISODES):
    obs, _ = env.reset()
    state = process_frame(obs)
    total_reward = 0
    done = False

    while not done:
        action = select_action(state)
        next_obs, reward, terminated, truncated, _ = env.step(action.item())
        done = terminated or truncated
        total_reward += reward

        next_state = process_frame(next_obs) if not done else None

        memory.push(state,
                    action,
                    torch.tensor([reward], dtype=torch.float32, device=device),
                    next_state,
                    torch.tensor([done], dtype=torch.float32, device=device))

        state = next_state if next_state is not None else state

        if steps_done % TRAIN_FREQ == 0:
            loss = optimize()
            loss_history.append(loss)
            writer.add_scalar("Loss", loss, steps_done)

            eps_threshold = EPS_END + (EPS_START - EPS_END) * np.exp(-steps_done / EPS_DECAY)
            writer.add_scalar("Epsilon", eps_threshold, steps_done)
            eps_history.append(eps_threshold)

            if len(memory) >= BATCH_SIZE:
                sample_transitions = memory.sample(BATCH_SIZE)
                sample_states = torch.cat([s for (s, _, _, _, _) in sample_transitions])
                with torch.no_grad():
                    q_values = policy_net(sample_states)
                avg_q = q_values.max(1)[0].mean().item()
                writer.add_scalar("Avg_Q", avg_q, steps_done)
                q_value_history.append(avg_q)

        if steps_done % TARGET_UPDATE == 0:
            target_net.load_state_dict(policy_net.state_dict())

    episode_rewards.append(total_reward)
    writer.add_scalar("Reward", total_reward, episode)

    if episode % 10 == 0:
        avg_reward = np.mean(episode_rewards[-10:])
        avg_loss = np.mean(loss_history[-100:]) if loss_history else 0
        print(f"Episode {episode:4d} | Avg Reward: {avg_reward:6.2f} | Loss: {avg_loss:6.4f}")

# Сохранение модели
torch.save(policy_net.state_dict(), "dqn_breakout_improved.pth")


# Построение графиков
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs[0, 0].set_title("Episode Rewards")
axs[0, 0].plot(episode_rewards)
axs[0, 0].set_xlabel("Episode")
axs[0, 0].set_ylabel("Reward")

axs[0, 1].set_title("Training Loss")
axs[0, 1].plot(loss_history)
axs[0, 1].set_xlabel("Training Steps")
axs[0, 1].set_ylabel("Loss")

axs[1, 0].set_title("Epsilon Decay")
axs[1, 0].plot(eps_history)
axs[1, 0].set_xlabel("Training Steps")
axs[1, 0].set_ylabel("Epsilon")

axs[1, 1].set_title("Average Q-Value")
axs[1, 1].plot(q_value_history)
axs[1, 1].set_xlabel("Training Steps")
axs[1, 1].set_ylabel("Avg Q")

plt.tight_layout()
plt.show()


env.close()
writer.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode    0 | Avg Reward:   1.00 | Loss: 0.0000
# Episode   10 | Avg Reward:   1.40 | Loss: 0.0000
# Episode   20 | Avg Reward:   0.80 | Loss: 0.0000
# Episode   30 | Avg Reward:   1.60 | Loss: 0.0000
# Episode   40 | Avg Reward:   1.00 | Loss: 0.0000
# Episode   50 | Avg Reward:   1.20 | Loss: 0.0000
# Episode   60 | Avg Reward:   1.20 | Loss: 0.0086
# Episode   70 | Avg Reward:   1.80 | Loss: 0.0083
# Episode   80 | Avg Reward:   2.20 | Loss: 0.0073
# Episode   90 | Avg Reward:   1.20 | Loss: 0.0051
# Episode  100 | Avg Reward:   1.50 | Loss: 0.0022
# Episode  110 | Avg Reward:   1.70 | Loss: 0.0053
# Episode  120 | Avg Reward:   1.50 | Loss: 0.0063
# Episode  130 | Avg Reward:   1.30 | Loss: 0.0080
# Episode  140 | Avg Reward:   1.80 | Loss: 0.0061
# Episode  150 | Avg Reward:   2.00 | Loss: 0.0064
# Episode  160 | Avg Reward:   1.90 | Loss: 0.0089
# Episode  170 | Avg Reward:   1.80 | Loss: 0.0071
# Episode  180 | Avg Reward:   1.50 | Loss: 0.0063
# Episode  190 | Avg Reward:   3.30 | Loss: 0.0091
# Episode  200 | Avg Reward:   3.00 | Loss: 0.0077
# Episode  210 | Avg Reward:   4.10 | Loss: 0.0095
# Episode  220 | Avg Reward:   2.70 | Loss: 0.0081
# Episode  230 | Avg Reward:   4.10 | Loss: 0.0113
# Episode  270 | Avg Reward:   3.70 | Loss: 0.0174
# Episode  280 | Avg Reward:   4.50 | Loss: 0.0181
# Episode  290 | Avg Reward:   3.90 | Loss: 0.0164
# Episode  300 | Avg Reward:   5.70 | Loss: 0.0104
# Episode  310 | Avg Reward:   4.40 | Loss: 0.0106
# Episode  320 | Avg Reward:   5.80 | Loss: 0.0127
# Episode  330 | Avg Reward:   5.40 | Loss: 0.0115
# Episode  340 | Avg Reward:   5.70 | Loss: 0.0192
# Episode  350 | Avg Reward:   4.00 | Loss: 0.0132
# Episode  360 | Avg Reward:   4.60 | Loss: 0.0109
# Episode  370 | Avg Reward:   5.60 | Loss: 0.0172
# Episode  380 | Avg Reward:   4.20 | Loss: 0.0218
# Episode  390 | Avg Reward:   4.60 | Loss: 0.0137
# Episode  400 | Avg Reward:   5.40 | Loss: 0.0182
# Episode  410 | Avg Reward:   5.50 | Loss: 0.0130
# Episode  420 | Avg Reward:   5.40 | Loss: 0.0259
# Episode  430 | Avg Reward:   6.10 | Loss: 0.0130
# Episode  440 | Avg Reward:   6.40 | Loss: 0.0138
# Episode  450 | Avg Reward:   5.60 | Loss: 0.0131
# Episode  460 | Avg Reward:   7.20 | Loss: 0.0110
# Episode  470 | Avg Reward:   6.00 | Loss: 0.0233
# Episode  480 | Avg Reward:   5.00 | Loss: 0.0164
# Episode  490 | Avg Reward:   6.40 | Loss: 0.0140
# Episode  500 | Avg Reward:   7.20 | Loss: 0.0134
# Episode  510 | Avg Reward:   5.00 | Loss: 0.0201
# Episode  520 | Avg Reward:   7.40 | Loss: 0.0131
# Episode  530 | Avg Reward:   5.90 | Loss: 0.0129
# Episode  540 | Avg Reward:   6.30 | Loss: 0.0132
# Episode  550 | Avg Reward:   7.60 | Loss: 0.0164
# Episode  560 | Avg Reward:   9.80 | Loss: 0.0120
# Episode  570 | Avg Reward:   6.30 | Loss: 0.0090
# Episode  580 | Avg Reward:   7.70 | Loss: 0.0154
# Episode  590 | Avg Reward:   7.40 | Loss: 0.0146
# Episode  600 | Avg Reward:   6.60 | Loss: 0.0145
# Episode  610 | Avg Reward:   8.60 | Loss: 0.0127
# Episode  620 | Avg Reward:  10.70 | Loss: 0.0176
# Episode  630 | Avg Reward:   6.80 | Loss: 0.0163
# Episode  640 | Avg Reward:  10.40 | Loss: 0.0103
# Episode  650 | Avg Reward:  13.00 | Loss: 0.0096
# Episode  660 | Avg Reward:   8.50 | Loss: 0.0096
# Episode  670 | Avg Reward:   9.40 | Loss: 0.0126
# Episode  680 | Avg Reward:   9.10 | Loss: 0.0117
# Episode  690 | Avg Reward:  11.20 | Loss: 0.0158
# Episode  700 | Avg Reward:   9.40 | Loss: 0.0124
# Episode  710 | Avg Reward:  10.10 | Loss: 0.0212
# Episode  720 | Avg Reward:  10.10 | Loss: 0.0125
# Episode  730 | Avg Reward:  12.00 | Loss: 0.0154
# Episode  740 | Avg Reward:   9.60 | Loss: 0.0133
# Episode  750 | Avg Reward:  12.50 | Loss: 0.0157
# Episode  760 | Avg Reward:  13.80 | Loss: 0.0113
# Episode  770 | Avg Reward:  14.00 | Loss: 0.0153
# Episode  780 | Avg Reward:  13.20 | Loss: 0.0109
# Episode  790 | Avg Reward:  10.10 | Loss: 0.0181
# Episode  800 | Avg Reward:  14.60 | Loss: 0.0135
# Episode  810 | Avg Reward:  15.00 | Loss: 0.0131
# Episode  820 | Avg Reward:  12.40 | Loss: 0.0216
# Episode  830 | Avg Reward:  14.90 | Loss: 0.0129
# Episode  840 | Avg Reward:  15.00 | Loss: 0.0152
# Episode  850 | Avg Reward:  13.90 | Loss: 0.0166
# Episode  860 | Avg Reward:  11.80 | Loss: 0.0184
# Episode  870 | Avg Reward:  13.60 | Loss: 0.0131
# Episode  880 | Avg Reward:  17.20 | Loss: 0.0153
# Episode  890 | Avg Reward:  16.20 | Loss: 0.0143
# Episode  900 | Avg Reward:  13.80 | Loss: 0.0142
# Episode  910 | Avg Reward:  14.90 | Loss: 0.0144
# Episode  920 | Avg Reward:  12.40 | Loss: 0.0141
# Episode  930 | Avg Reward:  14.00 | Loss: 0.0375
# Episode  940 | Avg Reward:  14.70 | Loss: 0.0229
# Episode  950 | Avg Reward:  14.00 | Loss: 0.0288
# Episode  960 | Avg Reward:  18.80 | Loss: 0.0206
# Episode  970 | Avg Reward:  15.30 | Loss: 0.0158
# Episode  980 | Avg Reward:  16.50 | Loss: 0.0202
# Episode  990 | Avg Reward:  15.30 | Loss: 0.0170
# Episode 1000 | Avg Reward:  15.60 | Loss: 0.0292
# Episode 1010 | Avg Reward:  15.80 | Loss: 0.0214
# Episode 1020 | Avg Reward:  13.90 | Loss: 0.0188
# Episode 1030 | Avg Reward:  13.70 | Loss: 0.0189
# Episode 1040 | Avg Reward:  15.20 | Loss: 0.0177
# Episode 1050 | Avg Reward:  16.00 | Loss: 0.0255
# Episode 1060 | Avg Reward:  14.90 | Loss: 0.0262
# Episode 1070 | Avg Reward:  16.90 | Loss: 0.0302
# Episode 1080 | Avg Reward:  18.20 | Loss: 0.0248
# Episode 1090 | Avg Reward:  14.20 | Loss: 0.0235
# Episode 1100 | Avg Reward:  11.90 | Loss: 0.0207
# Episode 1110 | Avg Reward:  14.60 | Loss: 0.0276
# Episode 1120 | Avg Reward:  13.30 | Loss: 0.0289
# Episode 1130 | Avg Reward:  14.50 | Loss: 0.0273
# Episode 1140 | Avg Reward:  20.70 | Loss: 0.0255
# Episode 1150 | Avg Reward:  15.30 | Loss: 0.0333
# Episode 1160 | Avg Reward:  17.10 | Loss: 0.0282
# Episode 1170 | Avg Reward:  12.60 | Loss: 0.0409
# Episode 1180 | Avg Reward:  15.90 | Loss: 0.0255
# Episode 1190 | Avg Reward:  20.00 | Loss: 0.0280
# Episode 1200 | Avg Reward:  21.70 | Loss: 0.0289
# Episode 1210 | Avg Reward:  16.20 | Loss: 0.0273
# Episode 1220 | Avg Reward:  18.60 | Loss: 0.0274
# Episode 1230 | Avg Reward:  15.40 | Loss: 0.0393
# Episode 1240 | Avg Reward:  19.20 | Loss: 0.0223
# Episode 1250 | Avg Reward:  19.10 | Loss: 0.0296
# Episode 1260 | Avg Reward:  14.70 | Loss: 0.0379
# Episode 1270 | Avg Reward:  15.30 | Loss: 0.0376
# Episode 1280 | Avg Reward:  16.20 | Loss: 0.0283
# Episode 1300 | Avg Reward:  15.00 | Loss: 0.0315
# Episode 1310 | Avg Reward:  15.10 | Loss: 0.0387
# Episode 1320 | Avg Reward:  17.50 | Loss: 0.0288
# Episode 1330 | Avg Reward:  15.70 | Loss: 0.0351
# Episode 1340 | Avg Reward:  15.30 | Loss: 0.0420
# Episode 1350 | Avg Reward:  14.60 | Loss: 0.0338
# Episode 1360 | Avg Reward:  17.10 | Loss: 0.0443
# Episode 1370 | Avg Reward:  17.40 | Loss: 0.0443
# Episode 1380 | Avg Reward:  16.60 | Loss: 0.0379
# Episode 1390 | Avg Reward:  19.60 | Loss: 0.0351
# Episode 1400 | Avg Reward:  20.50 | Loss: 0.0375
# Episode 1410 | Avg Reward:  20.70 | Loss: 0.0334
# Episode 1420 | Avg Reward:  17.30 | Loss: 0.0262
# Episode 1430 | Avg Reward:  21.50 | Loss: 0.0370
# Episode 1440 | Avg Reward:  13.60 | Loss: 0.0348
# Episode 1450 | Avg Reward:  18.20 | Loss: 0.0395
# Episode 1460 | Avg Reward:  10.70 | Loss: 0.0292
# Episode 1470 | Avg Reward:  12.90 | Loss: 0.0324
# Episode 1480 | Avg Reward:  20.70 | Loss: 0.0267
# Episode 1490 | Avg Reward:  19.80 | Loss: 0.0287
# Episode 1500 | Avg Reward:  13.80 | Loss: 0.0266
# Episode 1510 | Avg Reward:  17.20 | Loss: 0.0466
# Episode 1520 | Avg Reward:  21.70 | Loss: 0.0358
# Episode 1530 | Avg Reward:  20.90 | Loss: 0.0442
# Episode 1540 | Avg Reward:  14.70 | Loss: 0.0367
# Episode 1550 | Avg Reward:  18.60 | Loss: 0.0386
# Episode 1560 | Avg Reward:  15.80 | Loss: 0.0420
# Episode 1570 | Avg Reward:  15.00 | Loss: 0.0357
# Episode 1580 | Avg Reward:  14.70 | Loss: 0.0296
# Episode 1590 | Avg Reward:  13.60 | Loss: 0.0364
# Episode 1600 | Avg Reward:  16.50 | Loss: 0.0534
# Episode 1610 | Avg Reward:  19.10 | Loss: 0.0348
# Episode 1620 | Avg Reward:  19.20 | Loss: 0.0439
# Episode 1630 | Avg Reward:  19.60 | Loss: 0.0422
# Episode 1640 | Avg Reward:  23.00 | Loss: 0.0365
# Episode 1650 | Avg Reward:  14.70 | Loss: 0.0341
# Episode 1660 | Avg Reward:  19.00 | Loss: 0.0448
# Episode 1670 | Avg Reward:  23.10 | Loss: 0.0314
# Episode 1680 | Avg Reward:  16.30 | Loss: 0.0312
# Episode 1690 | Avg Reward:  13.30 | Loss: 0.0369
# Episode 1700 | Avg Reward:  20.20 | Loss: 0.0307
# Episode 1710 | Avg Reward:  17.90 | Loss: 0.0490
# Episode 1720 | Avg Reward:  19.30 | Loss: 0.0400
# Episode 1730 | Avg Reward:  20.30 | Loss: 0.0345
# Episode 1740 | Avg Reward:  22.80 | Loss: 0.0442
# Episode 1750 | Avg Reward:  18.30 | Loss: 0.0366
# Episode 1760 | Avg Reward:  19.00 | Loss: 0.0323
# Episode 1770 | Avg Reward:  22.90 | Loss: 0.0332
# Episode 1780 | Avg Reward:  20.70 | Loss: 0.0358
# Episode 1790 | Avg Reward:  17.40 | Loss: 0.0306
# Episode 1800 | Avg Reward:  20.20 | Loss: 0.0331
# Episode 1810 | Avg Reward:  15.70 | Loss: 0.0375
# Episode 1820 | Avg Reward:  16.30 | Loss: 0.0344
# Episode 1830 | Avg Reward:  19.80 | Loss: 0.0382
# Episode 1840 | Avg Reward:  20.50 | Loss: 0.0357
# Episode 1850 | Avg Reward:  14.50 | Loss: 0.0367
# Episode 1860 | Avg Reward:  22.90 | Loss: 0.0322
# Episode 1870 | Avg Reward:  19.60 | Loss: 0.0297
# Episode 1880 | Avg Reward:  21.70 | Loss: 0.0361
# Episode 1890 | Avg Reward:  27.60 | Loss: 0.0431
# Episode 1900 | Avg Reward:  19.80 | Loss: 0.0627
# Episode 1910 | Avg Reward:  20.40 | Loss: 0.0534
# Episode 1920 | Avg Reward:  12.30 | Loss: 0.0341
# Episode 1930 | Avg Reward:  18.40 | Loss: 0.0372
# Episode 1940 | Avg Reward:  21.40 | Loss: 0.0346
# Episode 1950 | Avg Reward:  13.20 | Loss: 0.0391
# Episode 1960 | Avg Reward:  19.20 | Loss: 0.0334
# Episode 1970 | Avg Reward:  18.60 | Loss: 0.0407
# Episode 1980 | Avg Reward:  20.60 | Loss: 0.0460
# Episode 1990 | Avg Reward:  23.70 | Loss: 0.0305

# %%
# -------------------------
# Демонстрация видео для Breakout
video_folder = "./video_breakout"
os.makedirs(video_folder, exist_ok=True)
demo_env = gym.make('ALE/Breakout-v5',
                    obs_type='rgb',
                    frameskip=4,
                    repeat_action_probability=0.25,
                    render_mode='rgb_array')
demo_env = gym.wrappers.ResizeObservation(demo_env, (84, 84))
demo_env = gym.wrappers.GrayScaleObservation(demo_env)
demo_env = gym.wrappers.FrameStack(demo_env, FRAME_STACK)
demo_env = RecordVideo(demo_env, video_folder=video_folder, episode_trigger=lambda ep: True)

obs, _ = demo_env.reset()
done = False
while not done:
    state = process_frame(obs)
    with torch.no_grad():
        action = policy_net(state).argmax(dim=1, keepdim=True)
    obs, reward, terminated, truncated, _ = demo_env.step(action.item())
    done = terminated or truncated
demo_env.close()

# Функция для отображения видео в Jupyter Notebook
def show_video(video_folder):
    mp4_files = glob.glob(os.path.join(video_folder, "*.mp4"))
    if len(mp4_files) > 0:
        video_path = mp4_files[0]
        video = open(video_path, "rb").read()
        video_encoded = base64.b64encode(video).decode("ascii")
        return HTML(f'<video width="640" height="480" controls><source src="data:video/mp4;base64,{video_encoded}" type="video/mp4"></video>')
    else:
        return "Видео не найдено"

# Отобразим видео для Breakout
show_video(video_folder)
# Out:
# /opt/conda/lib/python3.11/site-packages/gym/wrappers/record_video.py:75: UserWarning: WARN: Overwriting existing videos at /home/jovyan/work/video_breakout folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# /opt/conda/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# MoviePy - Building video /home/jovyan/work/video_breakout/rl-video-episode-0.mp4.
# MoviePy - Writing video /home/jovyan/work/video_breakout/rl-video-episode-0.mp4
# MoviePy - Done !
# MoviePy - video ready /home/jovyan/work/video_breakout/rl-video-episode-0.mp4
# <video width="640" height="480" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>
